# %%
# =============================================================================
# Phase 2 — Feature Engineering : Silver → Silver Featured
# Craigslist Used Vehicle Dataset
# =============================================================================

import logging
import time
from datetime import datetime
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.types import IntegerType

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s | %(levelname)s | %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S"
)
log = logging.getLogger("VehicleETL_SilverFeatured")

# =============================================================================
# CONFIG
# =============================================================================

CURRENT_YEAR = datetime.now().year + 1 

SILVER_PATH          = "hdfs:///user/vehicle_market/silver/vehicles_clean"
FEATURED_PATH = "hdfs:///user/vehicle_market/featured/vehicles_featured"

LUXURY_BRANDS = {
    "bmw", "mercedes-benz", "audi", "lexus", "cadillac", "lincoln",
    "porsche", "jaguar", "land rover", "infiniti", "acura", "volvo",
    "tesla", "maserati", "ferrari", "lamborghini", "genesis"
}

ALTERNATIVE_FUELS = {"electric", "hybrid", "other"}

# Features where nulls are expected due to missing source values
# These will not trigger a warning in the validation report
EXPECTED_NULL_FEATURES = {"price_per_mile", "depreciation_index"}

# %%
# =============================================================================
# 1. SPARK SESSION
# =============================================================================

spark = SparkSession.builder \
    .appName("VehicleMarket_SilverFeatured") \
    .enableHiveSupport() \
    .getOrCreate()

spark.sparkContext.setLogLevel("WARN")
spark.sparkContext.setCheckpointDir("hdfs:///user/vehicle_market/logs/checkpoints")

pipeline_start = time.time()
log.info("="*65)
log.info("  Phase 2 — Feature Engineering : Silver → Silver Featured")
log.info("="*65)
# Out:
# 2026-08-01 04:11:15 | INFO | =================================================================
# 2026-08-01 04:11:15 | INFO |   Phase 2 — Feature Engineering : Silver → Silver Featured
# 2026-08-01 04:11:15 | INFO | =================================================================

# %%
# =============================================================================
# 2. LOAD SILVER LAYER
# =============================================================================

log.info("Loading Silver layer...")
df = spark.read.parquet(SILVER_PATH)
record_count_in = df.count()
columns_in      = len(df.columns)          # stored once, not re-read later
log.info(f"  Records loaded : {record_count_in}")
log.info(f"  Columns loaded : {columns_in}")
# Out:
# 2026-08-01 04:11:15 | INFO | Loading Silver layer...
# 2026-08-01 04:11:16 | INFO |   Records loaded : 249044
# 2026-08-01 04:11:16 | INFO |   Columns loaded : 26

# %%
# =============================================================================
# 3. VEHICLE AGE & AGE GROUP
# Purpose : Vehicle age enables depreciation analysis, age-based pricing,
#           and inventory health assessment.
# Dashboards : Dashboard 1 (Avg Age KPI), Dashboard 3 (Age Distribution,
#              Price vs Age), Dashboard 2 (Price Trend by Year)
# =============================================================================

log.info("Feature 1/13 — vehicle_age, age_group...")

df = df.withColumn(
    "vehicle_age",
    (F.lit(CURRENT_YEAR) - F.col("year")).cast(IntegerType())
)

df = df.withColumn(
    "age_group",
    F.when(F.col("vehicle_age") <= 2,  "Nearly New (0-2 yrs)")
     .when(F.col("vehicle_age") <= 5,  "Recent (3-5 yrs)")
     .when(F.col("vehicle_age") <= 10, "Mid-Age (6-10 yrs)")
     .when(F.col("vehicle_age") <= 15, "Older (11-15 yrs)")
     .otherwise("Classic (15+ yrs)")
)
# Out:
# 2026-08-01 04:11:16 | INFO | Feature 1/13 — vehicle_age, age_group...

# %%
# =============================================================================
# 4. PRICE CATEGORY
# Purpose : Segments market into buyer-friendly price tiers for
#           detailed distribution analysis and affordability insights.
#           Use this for all business analytics and Tableau dashboards.
#           (See also price_band for lightweight streaming use.)
# Dashboards : Dashboard 2 (Price Distribution, Price Intelligence),
#              Dashboard 3 (Price vs Mileage scatter)
# =============================================================================

log.info("Feature 2/13 — price_category...")

df = df.withColumn(
    "price_category",
    F.when(F.col("price") < 5000,  "Budget (< $5K)")
     .when(F.col("price") < 15000, "Mid-Range ($5K-$15K)")
     .when(F.col("price") < 35000, "Premium ($15K-$35K)")
     .when(F.col("price") < 75000, "High-End ($35K-$75K)")
     .otherwise("Luxury ($75K+)")
)
# Out:
# 2026-08-01 04:11:16 | INFO | Feature 2/13 — price_category...

# %%
# =============================================================================
# 5. MILEAGE CATEGORY
# Purpose : Classifies vehicles by usage level, enabling buyers to
#           filter by mileage tier and supporting inventory health analysis.
# Dashboards : Dashboard 3 (Mileage Distribution, Price vs Mileage),
#              Dashboard 4 (Mileage by State)
# =============================================================================

log.info("Feature 3/13 — mileage_category...")

df = df.withColumn(
    "mileage_category",
    F.when(F.col("odometer") < 20000,  "Low (< 20K)")
     .when(F.col("odometer") < 60000,  "Moderate (20K-60K)")
     .when(F.col("odometer") < 100000, "High (60K-100K)")
     .when(F.col("odometer") < 150000, "Very High (100K-150K)")
     .otherwise("Extreme (150K+)")
)
# Out:
# 2026-08-01 04:11:16 | INFO | Feature 3/13 — mileage_category...

# %%
# =============================================================================
# 6. PRICE PER MILE
# Purpose : Measures cost efficiency — how much a buyer pays per mile
#           driven. Lower values indicate better value for money.
# Note    : Nulls are expected where odometer is null or zero.
#           This is valid behavior, not a data quality issue.
# Dashboards : Dashboard 3 (Vehicle value analysis, Price vs Mileage)
# =============================================================================

log.info("Feature 4/13 — price_per_mile...")

df = df.withColumn(
    "price_per_mile",
    F.when(
        F.col("odometer").isNotNull() & (F.col("odometer") > 0),
        F.round(F.col("price") / F.col("odometer"), 4)
    ).otherwise(None)
)
# Out:
# 2026-08-01 04:11:16 | INFO | Feature 4/13 — price_per_mile...

# %%
# =============================================================================
# 7. POSTING DATE FEATURES
# Purpose : Enables time-series analysis, seasonal trends, and
#           weekday/monthly listing activity patterns.
# Dashboards : Dashboard 1 (Listing Trend), Dashboard 5 (Live Trend)
# =============================================================================

log.info("Feature 5/13 — posting date features...")
    # .withColumn("posting_quarter",      F.quarter(F.col("posting_date"))) \
    # .withColumn("posting_month",        F.month(F.col("posting_date"))) \
 # .withColumn("posting_weekday",      F.dayofweek(F.col("posting_date"))) \
df = df \
    .withColumn("posting_year",         F.year(F.col("posting_date"))) \
    .withColumn("posting_day",          F.dayofmonth(F.col("posting_date"))) \
    .withColumn("posting_month",   F.date_format(F.col("posting_date"), "MMMM")) \
    .withColumn("posting_weekday", F.date_format(F.col("posting_date"), "EEEE")) \
    .withColumn("posting_hour",         F.hour(F.col("posting_date")))
# Out:
# 2026-08-01 04:11:16 | INFO | Feature 5/13 — posting date features...

# %%
df.show(truncate=False)
# Out:
# +------------+----------------+----------+------------------------------------------------------------------------------------------------+--------------+----------------------------------+-----+----+---------+-----------+------+--------+------------+------------+-----------------+-------+---------+-------+-----------+-------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------ ...
# |manufacturer|model           |id        |url                                                                                             |region        |region_url                        |price|year|condition|cylinders  |fuel  |odometer|title_status|transmission|VIN              |drive  |size     |type   |paint_color|image_url                                                          |description                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# +------------+----------------+----------+------------------------------------------------------------------------------------------------+--------------+----------------------------------+-----+----+---------+-----------+------+--------+------------+------------+-----------------+-------+---------+-------+-----------+-------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------ ...
# |bmw         |x5              |7307679724|https://abilene.craigslist.org/ctd/d/abilene-2002-bmw-x5/7307679724.html                        |abilene       |https://abilene.craigslist.org    |4500 |2002|unknown  |unknown    |gas   |184000  |clean       |automatic   |NULL             |unknown|unknown  |unknown|unknown    |https://images.craigslist.org/00m0m_iba78h8ty95_0fu0bC_600x450.jpg |$4,500 Cash  2002 BMW X5  8 cylinder 4.4L motor  Automatic transmission  184k miles Leather seats  Cold Ac and great heater This car runs great, has a new water pump! Leather seat are in good condition. Has some small issues with the interior.￼￼Does have some small blemishes. This is a great car, come by and take it for a test drive! Let’s make a deal!  Call or text BMW  512-653-0636 Stop by  LNC Auto Sales  1842 N First st Abilene Tx 79603                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ...
# |toyota      |camry           |7308988448|https://abilene.craigslist.org/ctd/d/abilene-2014-toyota-camry-le/7308988448.html               |abilene       |https://abilene.craigslist.org    |11125|2014|good     |4 cylinders|gas   |51534   |clean       |automatic   |4T4BF1FK1ER378075|fwd    |full-size|sedan  |grey       |https://images.craigslist.org/00Y0Y_lzoRI0OvfBGz_0CI0t2_600x450.jpg|2014 Grey Toyota Camry LE 4 dr with very clean light grey cloth interior. Automatic, Power Windows, Power Seat Drivers side, Power Locks, Mirrors, Tilt, Cruise, A/C, CD,  Steering wheel controls, Blue Tooth / Phone and USB Port, Back up Camera.  Economical 2.5 ltr  4 cylinder engine with (  51,534 miles. ) EPA estimates are 25 to 35 mpg & 27 mpg overall. This car has some minor Hail Damage and is offered at $11,125.00 plus the TT&l   ( Suggested Retail is $13200.00 before TT&l  and highly rated car by Consumers Reports ) Compare the value on this car to others and come check it out! You provide the financing through your bank or credit union etc ! Call or Text John @ 325 665 4176                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# |ford        |flex            |7314771666|https://abilene.craigslist.org/ctd/d/eastland-2015-ford-flex-sel/7314771666.html                |abilene       |https://abilene.craigslist.org    |18998|2015|unknown  |unknown    |gas   |82566   |clean       |automatic   |2FMGK5C82FBA15352|fwd    |unknown  |suv    |silver     |https://images.craigslist.org/00Y0Y_iWoee2QmKiz_0gw0co_600x450.jpg |Stanley Ford Eastland address:    1308 E Main St Eastland TX, 76448phone:      ☎ (254) 233-7208 ext 6text:       Text 6 to (254) 233-7208 for more details  link:       https://25045.dealerresources.net/s/45037668/2/22308585/6  contact:    Chris Koster   2015 FORD FLEX SEL Vehicle InfoStock #: BA15352A1VIN: 2FMGK5C82FBA15352Condition: UsedOdometer: 82566Fuel Efficiency: 18/25DrivetrainEngine: 3.5 liter V6 Cylinder EngineCylinders: 6Fuel Type: Gasoline FuelTransmission: 6-SPEED SELECTSHIFT AUTOMATICTransmission Type: 6-SPEED SELECTSHIFT AUTOMATICDrivetrain: FWDBody & InteriorExterior Color: SilverOEM Color Name: Ingot Silver MetallicInterior Color: Charcoal BlackDoors: 4Description Summary**CLEAN AUTOCHECK**, REMOTE START, PUSH BUTTON START, LEATHER, HEATED SEATS, MEMORY DRIVER'S SEAT, POWER PASSENGER SEAT, 3RD ROW SEATS, FORD MYKEY, SYNC W/ MYFORD TOUCH, BLUETOOTH for Hands-Free Phone, UNIVERSAL GARAGE DOOR OPENER, BLIND SPOT ALERT, FOG LAMPS, POWER LIFTGATE, REVERSE SENSING SYSTEM, REAR VIEW CAMERAVehicle DetailsWhy Buy Stanley?CONSIDER IT COVERED: We offer a 3 month/3,000 mile limited warranty with each and every vehicle. Take on the road, not the stress. (Excludes vehicles over 10 years and/or 130,000 milesNot all Vehicles will qualify, please see dealership for the complete list of Eligible Vehicles details.)SERVICE: Our technicians run a rigorous 172-point inspection and all factory recalls are performed before sale.LOCATION, LOCATION, LOCATION! Know exactly what you want but don't see it at your closest Stanley dealership? Don't let that stop you; we will ship any vehicle at one of our other locations to your hometown Stanley dealership. Start shopping the entire inventory at stanleyautogroup.com.FINANCE FINESSE: Find the perfect financing fit you're comfortable with through a wide range of various banks that meet all credit needs. Want warranty, GAP, or added aftermarket parts & upgrades? Pick our brain until you know all of the ins and outs.  WANT TO SAVE TIME?  Of course you do, who doesn't?  Fill out our online credit application and get pre-approved!MORE BANG FOR YOUR BUCK:  Do you have a trade in?  WE WANT IT!  Let us give you top dollar for your vehicle to get you one step closer to your dream car.BECOME A PART OF THE FAMILY:  Our staff is ready to serve you, providing outstanding customer service to fit your every need to exceed your expectations from beginning to end.  EquipmentThe state of the art park assist system will guide you easily into any spot. This model comes with third row seating for extra passengers. This 2015 Ford Flex has a 3.5 liter V6 Cylinder Engine high output engine. This vehicle gleams with an elegant silver clear coated finish. The vehicle is front wheel drive. The vehicle has an adjustable telescoping wheel that allows you to achieve a perfect fit for your driving comfort. Anti-lock brakes will help you stop in an emergency. Enjoy the tried and true gasoline engine in this Ford Flex. Easily set your speed in the Ford Flex with a state of the art cruise control system. Increase or decrease velocity with the touch of a button. This Ford Flex has an automatic transmission that includes a manual shifting mode. This mid-sized SUV is perfect for your next adventure.PackagesEQUIPMENT GROUP 202A: Rear View Camera; Memory Driver's Seat; memory for mirrors; Body-Color Liftgate Applique; Power Liftgate; BLIS Blind Spot Monitoring System; cross-traffic alert; Premium Audio System w/7 Speakers; 110V Power Outlet; Exterior Mirrors w/Security Approach Lamps; Adjustable Pedals w/Memory Equipment listed is based on original v ...
# |lincoln     |continental     |7302020814|https://abilene.craigslist.org/ctd/d/eastland-2017-lincoln-continental-select/7302020814.html   |abilene       |https://abilene.craigslist.org    |27500|2017|unknown  |unknown    |gas   |15912   |clean       |automatic   |1LN6L9SK4H5629128|fwd    |unknown  |sedan  |black      |https://images.craigslist.org/00404_5Qp1G15FM4Rz_0gw0co_600x450.jpg|Stanley Ford Eastland address:    1308 E Main St Eastland TX, 76448phone:      ☎ (254) 233-7208 ext 14text:       Text 14 to (254) 233-7208 for more details  link:       http://25045.cleancarsorg.com/l/44551317/2/22278464/14  contact:    Chris Koster   2017 LINCOLN CONTINENTAL SELECT Vehicle InfoStock #: 5629128AVIN: 1LN6L9SK4H5629128Condition: UsedOdometer: 
Main St Eastland TX, 76448phone:      ☎ (254) 233-7208 ext 16text:       Text 16 to (254) 233-7208 for more details  link:       https://25045.solidautonet.com/v/44600762/2/22279760/16  contact:    Chris Koster   2019 FORD F-150 XL Vehicle InfoStock #: KC47707TVIN: 1FTEX1EP8KKC47707Condition: UsedOdometer: 49661Fuel Efficiency: 19/24DrivetrainEngine: 2.7 liter V6 Cylinder EngineCylinders: 6Fuel Type: Gasoline FuelTransmission: ELECTRONIC 10-SPEED AUTOMATICTransmission Type: ELECTRONIC 10-SPEED AUTOMATICDrivetrain: 4WDBody & InteriorExterior Color: BlackOEM Color Name: Agate Black MetallicInterior Color: Dark Earth GrayDoors: 4Description Summary**ONE OWNER**, **CLEAN AUTOCHECK**, 4WD, XL POWER EQUIPMENT GROUP, SYNC 3, BLUETOOTH for Hands-Free Phone, CRUISE CONTROL, PRE-COLLISION ASSIST, 20" WHEELS, REAR VIEW CAMERAVehicle DetailsWhy Buy Stanley?CONSIDER IT COVERED: We offer a 3 month/3,000 mile limited warranty with each and every vehicle. Take on the road, not the stress. (Excludes vehicles over 10 years and/or 130,000 milesNot all Vehicles will qualify, please see dealership for the complete list of Eligible Vehicles details.)SERVICE: Our technicians run a rigorous 172-point inspection and all factory recalls are performed before sale.LOCATION, LOCATION, LOCATION! Know exactly what you want but don't see it at your closest Stanley dealership? Don't let that stop you; we will ship any vehicle at one of our other locations to your hometown Stanley dealership. Start shopping the entire inventory at stanleyautogroup.com.FINANCE FINESSE: Find the perfect financing fit you're comfortable with through a wide range of various banks that meet all credit needs. Want warranty, GAP, or added aftermarket parts & upgrades? Pick our brain until you know all of the ins and outs. WANT TO SAVE TIME? Of course you do, who doesn't? Fill out our online credit application and get pre-approved!MORE BANG FOR YOUR BUCK: Do you have a trade in? WE WANT IT! Let us give you top dollar for your vehicle to get you one step closer to your dream car.BECOME A PART OF THE FAMILY: Our staff is ready to serve you, providing outstanding customer service to fit your every need to exceed your expectations from beginning to end. EquipmentThis unit has four wheel drive capabilities. It is painted with a sleek and sophisticated black color. This model has a 2.7 liter V6 Cylinder Engine high output engine. Anti-lock brakes are standard on this vehicle. This 2019 Ford F-150 is equipped with a gasoline engine. Big enough to tow or haul, this 1/2 ton pickup has the space, power and durability for anyone.PackagesEQUIPMENT GROUP 101A MID: 4.2" Productivity Screen in Instrument Cluster; compass; SYNC; enhanced voice recognition communications and entertainment system; 911 assist; 4.2" LCD display in center stack; Applink and 1 smart charging USB port; XL Power Equipment Group; Power Door Locks; flip key and integrated key transmitter keyless-entry (includes Autolock); MyKey; Power Glass Sideview Mirrors w/Black Skull Caps; manual-folding; Power Front & Rear Windows; Power Tailgate Lock; Illuminated Entry; Perimeter Alarm; Cruise Control STX APPEARANCE PACKAGE: Box Side Decals; Fog Lamps; Tires: P275/55R20 BSW AT; 275/65R18 OWL all-season/all-terrain spare tire; SYNC 3; enhanced voice recognition communications and entertainment system; 8" LCD touchscreen in center stack w/swipe capability; AppLink; 911 Assist; Apple CarPlay and Android Auto and 2 smart charging USB ports; Wheels: 20" Machined-Aluminum; flash gray painted pockets; Body-Color Surround w/ ...
# |kia         |forte 5-door    |7308706434|https://akroncanton.craigslist.org/ctd/d/akron-2013-kia-forte-door-sx/7308706434.html           |akron / canton|https://akroncanton.craigslist.org|10985|2013|unknown  |4 cylinders|gas   |43425   |clean       |automatic   |KNAFW5A3XD5697763|fwd    |unknown  |wagon  |blue       |https://images.craigslist.org/00c0c_5WbHdjJGCZyz_0ak07K_600x450.jpg|2013 Kia Forte 5-Door SX -- $10,985       ☎ Call: (234) 260-4181  📱 Text  (234) 260-4181 Vehicle Information: 2013 Kia Forte 5-Door SXPrice:  $10,985    Year:  2013*      Make:  *Kia**      Model:  *Forte 5-Door**      Series:  *SX**      Body Style:  Wagon*    Stock Number:  CB3519    VIN:  KNAFW5A3XD5697763    Mileage:  43k    Engine:  2.4L CVVT DOHC MPFI 16-Valve I4 Engine    Transmission:  Automatic    Exterior Color:  Corsa Blue*    Interior Color:  Black*Make The Switch to Prestige!  All Makes and Models - All at Great Prices!   WE FINANCE EVERYONE  Rates as Low as 2.49% Bad CREDIT is not a Problem, Guaranteed Credit Approval!  Make The Switch to Prestige! All Makes and Models - All at Great Prices! WE FINANCE EVERYONE Rates as Low as 2.49% BAD CREDIT is not a Problem, Guaranteed Credit Approval! Get started by paste the link in your browser:http://aswt.co/da1oz             For more details, pictures and information on this ***Kia**** ***Forte 5-Door**** ***SX****, Paste the link below into your browser:                http://aswt.co/da1o6                 Vehicle Options For This *Kia** *Forte 5-Door**:                             ✅ Wagon*                ✅ (2) front/(2) rear cup holders -inc: front chrome ring trim                ✅ 17 x 7 10-spoke alloy wheels                ✅ 2.4L CVVT DOHC MPFI 16-valve I4 engine -inc: engine cover                ✅ 215/45R17 tires                ✅ 3-point height-adjustable front seat belts w/pretensioners & force limiters                ✅ 3-point rear seat belts for all positions                ✅ 4-wheel anti-lock braking system (ABS)                ✅ 5-MPH bumpers                ✅ 6-speed electronically-controlled automatic transmission w/OD -inc: paddle shifters                ✅ 60/40 split-folding rear bench seat w/adjustable headrests -inc: center armrest, cushion/back fold-flat feature                ✅ AM/FM stereo w/CD/MP3 player -inc: aux input jack, USB port, (6) speakers w/door-mounted tweeters                ✅ Air conditioning                ✅ Bluetooth hands-free link -inc: steering wheel controls                ✅ Body-color bumpers                ✅ Body-color door handles                ✅ Body-color heated pwr folding mirrors w/integrated turn signals                ✅ Brake assist system (BAS)                ✅ Bright chrome decor accents -inc: transmission gear shift knob, park brake button, door handles, cluster housing                ✅ Cargo area light                ✅ Cargo cover                ✅ Cargo tray & under-floor cargo luggage box                ✅ Carpeted floor mats                ✅ Center console w/armrest & storage                ✅ Chrome exhaust tip                ✅ Clear-lens headlamps w/auto-on/off                ✅ Cruise control                ✅ Digital clock                ✅ Door & rear quarter solar control glass                ✅ Dual 12V pwr outlets                ✅ Dual front advanced airbags -inc: passenger occupancy sensor                ✅ Dual illuminated visor vanity mirrors w/extensions                ✅ Dual map lights                ✅ EcoMinder fuel efficiency monitor                ✅ Electronic brake force distribution (EBD)                ✅ Electronic stability control (ESC) w/traction control system (TCS)                ✅ Front bucket seats w/active headrests -inc: 6-way manual driver seat                ✅ Front door map pockets w/bottle holders                ✅ Front fog lamps                ✅ Front seat side mounted airbags                                                        ☎ Call (234) 260-4181   or 📱 Text  (234) 260-4181  to find out more about this ***Ki ...
# +------------+----------------+----------+------------------------------------------------------------------------------------------------+--------------+----------------------------------+-----+----+---------+-----------+------+--------+------------+------------+-----------------+-------+---------+-------+-----------+-------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------ ...
# only showing top 20 rows

# %%
# =============================================================================
# 8. POSTING SEASON
# Purpose : Groups months into seasons for seasonal listing trend
#           analysis. Complements month and quarter features.
# Dashboards : Dashboard 1 (Listing Trend seasonal filter)
# Mapping   : Winter = Dec, Jan, Feb
#             Spring = Mar, Apr, May
#             Summer = Jun, Jul, Aug
#             Fall   = Sep, Oct, Nov
# =============================================================================

# log.info("Feature 6/13 — posting_season...")

# df = df.withColumn(
#     "posting_season",
#     F.when(F.col("posting_month").isin("December", "January", "February"), "Winter")
#      .when(F.col("posting_month").isin("March", "April", "May"),            "Spring")
#      .when(F.col("posting_month").isin("June", "July", "August"),           "Summer")
#      .when(F.col("posting_month").isin("September", "October", "November"), "Fall")
#      .otherwise(None)
# )

# %%
# =============================================================================
# 8b. WEEKEND FLAG & POSTING PERIOD
# Purpose : is_weekend enables weekend vs weekday listing behaviour analysis.
#           posting_period segments the day into time-of-day business dimensions.
# Dashboards : Dashboard 1 (Listing activity patterns), Dashboard 5 (Live filters)
# =============================================================================

log.info("Feature 14/16 — is_weekend, posting_period...")

df = df.withColumn(
    "is_weekend",
    F.when(F.col("posting_weekday").isin("Saturday", "Sunday"), True)
     .otherwise(False)
)

df = df.withColumn(
    "posting_period",
    F.when(F.col("posting_hour").between(0, 5),   "Night")
     .when(F.col("posting_hour").between(6, 11),  "Morning")
     .when(F.col("posting_hour").between(12, 17), "Afternoon")
     .otherwise("Evening")
)
# Out:
# 2026-08-01 04:11:17 | INFO | Feature 14/16 — is_weekend, posting_period...

# %%
df = df.drop('posting_hour')

# %%
# =============================================================================
# 9. LUXURY BRAND FLAG
# Purpose : Identifies premium manufacturer listings to support luxury
#           segment analysis and premium pricing trends.
# Dashboards : Dashboard 2 (Top Premium Models, Price Intelligence)
# =============================================================================

log.info("Feature 7/13 — is_luxury...")

df = df.withColumn(
    "is_luxury",
    F.when(F.col("manufacturer").isin(list(LUXURY_BRANDS)), True)
     .otherwise(False)
)
# Out:
# 2026-08-01 04:11:17 | INFO | Feature 7/13 — is_luxury...

# %%
# =============================================================================
# 10. ALTERNATIVE FUEL FLAG
# Purpose : Isolates EV, hybrid, and non-gasoline vehicles for
#           fuel trend and market shift analysis.
# Dashboards : Dashboard 1 (Fuel Distribution), Dashboard 2 (Price by Fuel)
# =============================================================================

log.info("Feature 8/13 — is_alternative_fuel...")

df = df.withColumn(
    "is_alternative_fuel",
    F.when(F.col("fuel").isin(list(ALTERNATIVE_FUELS)), True)
     .otherwise(False)
)
# Out:
# 2026-08-01 04:11:18 | INFO | Feature 8/13 — is_alternative_fuel...

# %%
# =============================================================================
# 11. AUTOMATIC TRANSMISSION FLAG
# Purpose : Identifies vehicles with automatic transmission to support
#           transmission market analysis and executive KPI reporting.
# Dashboards : Dashboard 2 (Transmission Analysis),
#              Dashboard 3 (Automatic % KPI)
# =============================================================================

log.info("Feature 9/13 — is_automatic...")

df = df.withColumn(
    "is_automatic",
    F.when(
        F.lower(F.col("transmission")) == "automatic",
        True
    ).otherwise(False)
)
# Out:
# 2026-08-01 04:11:18 | INFO | Feature 9/13 — is_automatic...

# %%
# =============================================================================
# 12. VEHICLE SEGMENT
# Purpose : Groups vehicle types into market segments for inventory
#           analysis and buyer preference insights.
# Dashboards : Dashboard 3 (Vehicle Type Analysis, Inventory treemap)
# =============================================================================

log.info("Feature 10/12 — vehicle_segment...")

df = df.withColumn(
    "vehicle_segment",
    F.when(F.col("type").isin("sedan", "coupe", "hatchback", "convertible"),
           "Passenger Car")
     .when(F.col("type").isin("suv", "offroad"),
           "SUV / Off-Road")
     .when(F.col("type").isin("truck", "pickup"),
           "Truck")
     .when(F.col("type").isin("van", "mini-van"),
           "Van / Minivan")
     .when(F.col("type").isin("wagon"),
           "Wagon")
     .when(F.col("type").isin("bus"),
           "Bus / Commercial")
     .otherwise("Other / Unknown")
)
# Out:
# 2026-08-01 04:11:18 | INFO | Feature 10/12 — vehicle_segment...

# %%
# =============================================================================
# 13. CLEAN TITLE FLAG
# Purpose : Binary indicator for title quality. Supports inventory
#           health KPIs and risk-aware pricing analysis.
# Dashboards : Dashboard 3 (Title Status, Clean Title % KPI)
# =============================================================================

log.info("Feature 11/13 — clean_title...")

df = df.withColumn(
    "clean_title",
    F.when(F.col("title_status") == "clean", True).otherwise(False)
)
# Out:
# 2026-08-01 04:11:18 | INFO | Feature 11/13 — clean_title...

# %%
# =============================================================================
# 14. SALVAGE FLAG
# Purpose : Isolates salvage/rebuilt title vehicles for risk analysis
#           and price impact studies.
# Dashboards : Dashboard 3 (Salvage % KPI)
# =============================================================================

log.info("Feature 12/13 — is_salvage...")

df = df.withColumn(
    "is_salvage",
    F.when(F.col("title_status").isin("salvage", "rebuilt"), True)
     .otherwise(False)
)
# Out:
# 2026-08-01 04:11:19 | INFO | Feature 12/13 — is_salvage...

# %%
# =============================================================================
# 15. PRICE BAND
# Purpose : Lightweight 3-tier price classification designed for
#           real-time streaming aggregations where price_category
#           is too granular for low-latency computation.
#           price_category → detailed business analytics (Tableau)
#           price_band     → lightweight real-time aggregations (Kafka/HBase)
# Dashboards : Dashboard 5 (Live Manufacturer Ranking, Live Fuel Distribution)
# =============================================================================

# log.info("Feature 13/13 — price_band...")

# df = df.withColumn(
#     "price_band",
#     F.when(F.col("price") < 10000, "Low")
#      .when(F.col("price") < 30000, "Mid")
#      .otherwise("High")
# )

# %%
# =============================================================================
# 16. DEPRECIATION INDEX
# Purpose : Measures value retained per year of age. Lower values indicate
#           faster depreciation. Strongest additional business feature for
#           resale analysis, manufacturer value retention, and pricing trends.
# Note    : Nulls expected where vehicle_age <= 0 (current-year vehicles)
#           or price is null. Nulls are handled gracefully by Spark aggregations.
# Dashboards : Dashboard 2 (Manufacturer value retention, Depreciation trends)
# =============================================================================

log.info("Feature 16/16 — depreciation_index...")

df = df.withColumn(
    "depreciation_index",
    F.when(
        F.col("vehicle_age").isNull() |
        (F.col("vehicle_age") <= 0)  |
        F.col("price").isNull(),
        None
    ).otherwise(
        F.round(F.col("price") / F.col("vehicle_age"), 2)
    )
)
# Out:
# 2026-08-01 04:11:19 | INFO | Feature 16/16 — depreciation_index...

# %%
df = (
    df.withColumn("posting_dates", F.to_date(F.col("posting_date")))
      .withColumn("posting_time", F.date_format(F.col("posting_date"), "HH:mm:ss"))
)
df = df.drop("posting_date")

# %%
df.columns
# Out:
# ['manufacturer',
#  'model',
#  'id',
#  'url',
#  'region',
#  'region_url',
#  'price',
#  'year',
#  'condition',
#  'cylinders',
#  'fuel',
#  'odometer',
#  'title_status',
#  'transmission',
#  'VIN',
#  'drive',
#  'size',
#  'type',
#  'paint_color',
#  'image_url',
#  'description',
#  'state',
#  'lat',
#  'long',
#  'state_name',
#  'vehicle_age',
#  'age_group',
#  'price_category',
#  'mileage_category',
#  'price_per_mile',
#  'posting_year',
#  'posting_day',
#  'posting_month',
#  'posting_weekday',
#  'is_weekend',
#  'posting_period',
#  'is_luxury',
#  'is_alternative_fuel',
#  'is_automatic',
#  'vehicle_segment',
#  'clean_title',
#  'is_salvage',
#  'depreciation_index',
#  'posting_dates',
#  'posting_time']

# %%
df.printSchema()
# Out:
# root
#  |-- manufacturer: string (nullable = true)
#  |-- model: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- url: string (nullable = true)
#  |-- region: string (nullable = true)
#  |-- region_url: string (nullable = true)
#  |-- price: string (nullable = true)
#  |-- year: string (nullable = true)
#  |-- condition: string (nullable = true)
#  |-- cylinders: string (nullable = true)
#  |-- fuel: string (nullable = true)
#  |-- odometer: string (nullable = true)
#  |-- title_status: string (nullable = true)
#  |-- transmission: string (nullable = true)
#  |-- VIN: string (nullable = true)
#  |-- drive: string (nullable = true)
#  |-- size: string (nullable = true)
#  |-- type: string (nullable = true)
#  |-- paint_color: string (nullable = true)
#  |-- image_url: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- state: string (nullable = true)
#  |-- lat: float (nullable = true)
#  |-- long: float (nullable = true)
#  |-- state_name: string (nullable = true)
#  |-- vehicle_age: integer (nullable = true)
#  |-- age_group: string (nullable = false)
#  |-- price_category: string (nullable = false)
#  |-- mileage_category: string (nullable = false)
#  |-- price_per_mile: double (nullable = true)
#  |-- posting_year: integer (nullable = true)
#  |-- posting_day: integer (nullable = true)
#  |-- posting_month: string (nullable = true)
#  |-- posting_weekday: string (nullable = true)
#  |-- is_weekend: boolean (nullable = false)
#  |-- posting_period: string (nullable = false)
#  |-- is_luxury: boolean (nullable = false)
#  |-- is_alternative_fuel: boolean (nullable = false)
#  |-- is_automatic: boolean (nullable = false)
#  |-- vehicle_segment: string (nullable = false)
#  |-- clean_title: boolean (nullable = false)
#  |-- is_salvage: boolean (nullable = false)
#  |-- depreciation_index: double (nullable = true)
#  |-- posting_dates: date (nullable = true)
#  |-- posting_time: string (nullable = true)

# %%
# =============================================================================
# 17. CHECKPOINT
# =============================================================================

log.info("Checkpoint — resetting query plan after feature engineering...")
df = df.checkpoint()
log.info("Checkpoint written.")
# Out:
# 2026-08-01 04:11:21 | INFO | Checkpoint — resetting query plan after feature engineering...
# 2026-08-01 04:11:23 | INFO | Checkpoint written.

# %%
# =============================================================================
# 18. WRITE SILVER FEATURED TO HDFS
# =============================================================================

log.info(f"Writing Featured Dataset to: {FEATURED_PATH}")
df.write.mode("overwrite").parquet(FEATURED_PATH)
# df.write \
#   .option("compression", "uncompressed") \
#   .mode("overwrite") \
#   .parquet(FEATURED_PATH)
log.info("  Featured Dataset written.")
# Out:
# 2026-08-01 04:11:23 | INFO | Writing Featured Dataset to: hdfs:///user/vehicle_market/featured/vehicles_featured
# 2026-08-01 04:11:25 | INFO |   Featured Dataset written.

# %%
# =============================================================================
# 19. VALIDATION REPORT
# =============================================================================

record_count_out = df.count()
columns_out      = len(df.columns)
pipeline_end     = time.time()
execution_time   = round(pipeline_end - pipeline_start, 2)

NEW_FEATURES = [
    # Vehicle age
    "vehicle_age", "age_group",
    # Price features
    "price_category", "price_per_mile", "depreciation_index",
    # Mileage
    "mileage_category",
    # Posting date features (active only)
    "posting_year", "posting_month", "posting_day",
    "posting_weekday", "posting_dates",
    # Posting behaviour
    "is_weekend", "posting_period",
    # Vehicle flags
    "is_luxury", "is_alternative_fuel", "is_automatic",
    "clean_title", "is_salvage",
    # Vehicle classification
    "vehicle_segment",
]

log.info("\n" + "="*65)
log.info("     SILVER FEATURED — VALIDATION REPORT")
log.info("="*65)
log.info(f"  Execution Time          : {execution_time}s")
log.info(f"  Records In  (Silver)    : {record_count_in}")
log.info(f"  Records Out (Featured)  : {record_count_out}")
log.info(f"  Columns In              : {columns_in}")
log.info(f"  Columns Out             : {columns_out}")
log.info(f"  Features Added          : {columns_out - columns_in}")
log.info("")
log.info("  Feature Null Check:")
log.info(f"  {'Feature':<30} {'Nulls':>8} {'Null%':>8}  Status")
log.info(f"  {'-'*60}")

all_passed = True
for feat in NEW_FEATURES:
    null_count = df.filter(F.col(feat).isNull()).count()
    null_pct   = null_count / record_count_out * 100

    if feat in EXPECTED_NULL_FEATURES:
        status = "— Expected nulls (missing source values)"
    elif null_pct == 0:
        status = "✓ OK"
    else:
        status     = "⚠ UNEXPECTED — review required"
        all_passed = False

    log.info(f"  {feat:<30} {null_count:>8} {null_pct:>7.2f}%  {status}")

log.info("")
if all_passed:
    log.info("  ✓ All features passed validation.")
else:
    log.info("  ⚠ Unexpected nulls detected — review flagged features.")

log.info("")
log.info("  Sample Feature Distributions:")
df.groupBy("age_group").count().orderBy("age_group").show(truncate=False)
df.groupBy("price_category").count().orderBy(F.desc("count")).show(truncate=False)
# df.groupBy("posting_season").count().orderBy(F.desc("count")).show(truncate=False)
df.groupBy("vehicle_segment").count().orderBy(F.desc("count")).show(truncate=False)
# df.groupBy("price_band").count().orderBy(F.desc("count")).show(truncate=False)
df.groupBy("is_weekend").count().orderBy("is_weekend").show(truncate=False)
df.groupBy("posting_period").count().orderBy(F.desc("count")).show(truncate=False)

log.info("")
log.info("  Final Schema:")
df.printSchema()
log.info("="*65)
log.info("  Featured Dataset complete. Ready for Hive / Tableau.")
log.info("="*65)
# Out:
# 2026-08-01 04:11:26 | INFO |
# =================================================================
# 2026-08-01 04:11:26 | INFO |      SILVER FEATURED — VALIDATION REPORT
# 2026-08-01 04:11:26 | INFO | =================================================================
# 2026-08-01 04:11:26 | INFO |   Execution Time          : 10.41s
# 2026-08-01 04:11:26 | INFO |   Records In  (Silver)    : 249044
# 2026-08-01 04:11:26 | INFO |   Records Out (Featured)  : 249044
# 2026-08-01 04:11:26 | INFO |   Columns In              : 26
# 2026-08-01 04:11:26 | INFO |   Columns Out             : 45
# 2026-08-01 04:11:26 | INFO |   Features Added          : 19
# 2026-08-01 04:11:26 | INFO |
# 2026-08-01 04:11:26 | INFO |   Feature Null Check:
# 2026-08-01 04:11:26 | INFO |   Feature                           Nulls    Null%  Status
# 2026-08-01 04:11:26 | INFO |   ------------------------------------------------------------
# 2026-08-01 04:11:26 | INFO |   vehicle_age                           0    0.00%  ✓ OK
# 2026-08-01 04:11:26 | INFO |   age_group                             0    0.00%  ✓ OK
# 2026-08-01 04:11:26 | INFO |   price_category                        0    0.00%  ✓ OK
# 2026-08-01 04:11:26 | INFO |   price_per_mile                      547    0.22%  — Expected nulls (missing source values)
# 2026-08-01 04:11:26 | INFO |   depreciation_index                    0    0.00%  — Expected nulls (missing source values)
# 2026-08-01 04:11:26 | INFO |   mileage_category                      0    0.00%  ✓ OK
# 2026-08-01 04:11:26 | INFO |   posting_year                          0    0.00%  ✓ OK
# 2026-08-01 04:11:27 | INFO |   posting_month                         0    0.00%  ✓ OK
# 2026-08-01 04:11:27 | INFO |   posting_day                           0    0.00%  ✓ OK
# 2026-08-01 04:11:27 | INFO |   posting_weekday                       0    0.00%  ✓ OK
# 2026-08-01 04:11:27 | INFO |   posting_dates                         0    0.00%  ✓ OK
# 2026-08-01 04:11:27 | INFO |   is_weekend                            0    0.00%  ✓ OK
# 2026-08-01 04:11:27 | INFO |   posting_period                        0    0.00%  ✓ OK
# 2026-08-01 04:11:27 | INFO |   is_luxury                             0    0.00%  ✓ OK
# 2026-08-01 04:11:28 | INFO |   is_alternative_fuel                   0    0.00%  ✓ OK
# 2026-08-01 04:11:28 | INFO |   is_automatic                          0    0.00%  ✓ OK
# 2026-08-01 04:11:28 | INFO |   clean_title                           0    0.00%  ✓ OK
# 2026-08-01 04:11:28 | INFO |   is_salvage                            0    0.00%  ✓ OK
# 2026-08-01 04:11:28 | INFO |   vehicle_segment                       0    0.00%  ✓ OK
# 2026-08-01 04:11:28 | INFO |
# 2026-08-01 04:11:28 | INFO |   ✓ All features passed validation.
# 2026-08-01 04:11:28 | INFO |
# 2026-08-01 04:11:28 | INFO |   Sample Feature Distributions:
# +------------------+------+
# |age_group         |count |
# +------------------+------+
# |Classic (15+ yrs) |117460|
# |Mid-Age (6-10 yrs)|49713 |
# |Older (11-15 yrs) |81790 |
# |Recent (3-5 yrs)  |81    |
# +------------------+------+
#
# +--------------------+------+
# |price_category      |count |
# +--------------------+------+
# |Mid-Range ($5K-$15K)|101714|
# |Premium ($15K-$35K) |72846 |
# |Budget (< $5K)      |53074 |
# |High-End ($35K-$75K)|20141 |
# |Luxury ($75K+)      |1269  |
# +--------------------+------+
#
# +----------------+-----+
# |vehicle_segment |count|
# +----------------+-----+
# |Other / Unknown |77801|
# |Passenger Car   |72290|
# |SUV / Off-Road  |48178|
# |Truck           |36156|
# |Van / Minivan   |8584 |
# |Wagon           |5612 |
# |Bus / Commercial|423  |
# +----------------+-----+
#
# +----------+------+
# |is_weekend|count |
# +----------+------+
# |false     |184299|
# |true      |64745 |
# +----------+------+
# 2026-08-01 04:11:29 | INFO |
# 2026-08-01 04:11:29 | INFO |   Final Schema:
# 2026-08-01 04:11:29 | INFO | =================================================================
# 2026-08-01 04:11:29 | INFO |   Featured Dataset complete. Ready for Hive / Tableau.
# 2026-08-01 04:11:29 | INFO | =================================================================
# +--------------+------+
# |posting_period|count |
# +--------------+------+
# |Evening       |113741|
# |Night         |92793 |
# |Morning       |29192 |
# |Afternoon     |13318 |
# +--------------+------+
#
# root
#  |-- manufacturer: string (nullable = true)
#  |-- model: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- url: string (nullable = true)
#  |-- region: string (nullable = true)
#  |-- region_url: string (nullable = true)
#  |-- price: string (nullable = true)
#  |-- year: string (nullable = true)
#  |-- condition: string (nullable = true)
#  |-- cylinders: string (nullable = true)
#  |-- fuel: string (nullable = true)
#  |-- odometer: string (nullable = true)
#  |-- title_status: string (nullable = true)
#  |-- transmission: string (nullable = true)
#  |-- VIN: string (nullable = true)
#  |-- drive: string (nullable = true)
#  |-- size: string (nullable = true)
#  |-- type: string (nullable = true)
#  |-- paint_color: string (nullable = true)
#  |-- image_url: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- state: string (nullable = true)
#  |-- lat: float (nullable = true)
#  |-- long: float (nullable = true)
#  |-- state_name: string (nullable = true)
#  |-- vehicle_age: integer (nullable = true)
#  |-- age_group: string (nullable = false)
#  |-- price_category: string (nullable = false)
#  |-- mileage_category: string (nullable = false)
#  |-- price_per_mile: double (nullable = true)
#  |-- posting_year: integer (nullable = true)
#  |-- posting_day: integer (nullable = true)
#  |-- posting_month: string (nullable = true)
#  |-- posting_weekday: string (nullable = true)
#  |-- is_weekend: boolean (nullable = false)
#  |-- posting_period: string (nullable = false)
#  |-- is_luxury: boolean (nullable = false)
#  |-- is_alternative_fuel: boolean (nullable = false)
#  |-- is_automatic: boolean (nullable = false)
#  |-- vehicle_segment: string (nullable = false)
#  |-- clean_title: boolean (nullable = false)
#  |-- is_salvage: boolean (nullable = false)
#  |-- depreciation_index: double (nullable = true)
#  |-- posting_dates: date (nullable = true)
#  |-- posting_time: string (nullable = true)

# %%
from pyspark.sql import functions as F

print("=" * 70)
print("Vehicle Type → Vehicle Segment Verification")
print("=" * 70)

# Original vehicle types
print("\nOriginal 'type' values:")
df.groupBy("type") \
  .count() \
  .orderBy(F.desc("count")) \
  .show(50, truncate=False)

print("\n" + "=" * 70)

# Engineered vehicle segments
print("\nEngineered vehicle segments:")
df.groupBy("vehicle_segment") \
  .count() \
  .orderBy(F.desc("count")) \
  .show(truncate=False)

print("\n" + "=" * 70)

# Show which original types became "Other / Unknown"
print("\nVehicle types mapped to 'Other / Unknown':")

df.filter(F.col("vehicle_segment") == "Other / Unknown") \
  .groupBy("type") \
  .count() \
  .orderBy(F.desc("count")) \
  .show(50, truncate=False)
# Out:
# ======================================================================
# Vehicle Type → Vehicle Segment Verification
# ======================================================================
#
# Original 'type' values:
# +-----------+-----+
# |type       |count|
# +-----------+-----+
# |unknown    |71488|
# |sedan      |50502|
# |suv        |47706|
# |truck      |18542|
# |pickup     |17614|
# |coupe      |8762 |
# |hatchback  |8465 |
# |other      |6313 |
# |wagon      |5612 |
# |van        |4708 |
# |convertible|4561 |
# |mini-van   |3876 |
# |offroad    |472  |
# |bus        |423  |
# +-----------+-----+
#
#
# ======================================================================
#
# Engineered vehicle segments:
# +----------------+-----+
# |vehicle_segment |count|
# +----------------+-----+
# |Other / Unknown |77801|
# |Passenger Car   |72290|
# |SUV / Off-Road  |48178|
# |Truck           |36156|
# |Van / Minivan   |8584 |
# |Wagon           |5612 |
# |Bus / Commercial|423  |
# +----------------+-----+
#
#
# ======================================================================
#
# Vehicle types mapped to 'Other / Unknown':
# +-------+-----+
# |type   |count|
# +-------+-----+
# |unknown|71488|
# |other  |6313 |
# +-------+-----+

# %%
df.coalesce(1) \
    .write \
    .mode("overwrite") \
    .option("header", "true") \
    .option("quote", '"') \
    .option("escape", '"') \
    .option("quoteAll", "true") \
    .csv("/Users/huntstar/Projects/Vehical_Project/vehicles_featured_tableau/vehicle_cleaned")
